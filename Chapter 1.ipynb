# %%
using PyPlot

# %%
pic = [1  2  3  4  1  1  2  1;
       2  2  3  2  1  2  2  1;
       3  1 38 39 37 36  3  1;
       4  1 45 44 41 42  2  1;
       1  2 43 44 40 39  1  3;
       2  1 39 41 42 40  2  1;
       1  2  1  2  2  3  1  1;
       1  2  1  3  1  1  4  2]
# Out:
# 8x8 Array{Int64,2}:
#  1  2   3   4   1   1  2  1
#  2  2   3   2   1   2  2  1
#  3  1  38  39  37  36  3  1
#  4  1  45  44  41  42  2  1
#  1  2  43  44  40  39  1  3
#  2  1  39  41  42  40  2  1
#  1  2   1   2   2   3  1  1
#  1  2   1   3   1   1  4  2

# %%
pic[3, 3]
# Out:
# 38

# %%
pic[4, 3]
# Out:
# 45

# %%
plot_wireframe(linspace(1, 8, 8), linspace(1, 8, 8), pic)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1069e7d50>)
# PyObject <mpl_toolkits.mplot3d.art3d.Line3DCollection object at 0x10e24d810>

# %%
imshow(pic)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10d9f9110>)
# PyObject <matplotlib.image.AxesImage object at 0x10d885950>
